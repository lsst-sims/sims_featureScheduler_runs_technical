# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles
import glob
from combo_dust import make_rolling_footprints

# %%
outdir = 'rolling_maps'
resultsDb = db.ResultsDb(outDir=outdir)
db_files = glob.glob('*nslice*.db')
names = [name.replace('_v1.6.1_10yrs.db', '') for name in db_files]

# %%
for name, filename in zip(names, db_files):
    conn = db.OpsimDatabase(filename)
    
    bundleList = []
    sql = 'night > %f and night < %f and note not like "DD%%"' % ((365.25*3.5), (365.25*4.5) )
    metric = metrics.CountMetric('filter')
    slicer = slicers.HealpixSlicer()
    summaryStats = []
    plotDict = {'xlabel': 'Number of Observations', 'title':name, 'colorMin':0, 'colorMax': 200}
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql,
                                                 plotDict=plotDict,
                                                 summaryMetrics=summaryStats,
                                                 runName=name))
    bd = metricBundles.makeBundlesDictFromList(bundleList)
    bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outdir, resultsDb=resultsDb)
    bg.runAll()
    bg.plotAll(closefigs=False)
    conn.close()
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 222363 visits
# Running:  ['combo_dust_scale1_0_nslice3_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 64.0514  dipole: lon: -7.6398, lat: -68.5579, amp: 30.008
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 222324 visits
# Running:  ['combo_dust_scale0_9_nslice3_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 63.0963  dipole: lon: -8.22809, lat: -71.6093, amp: 30.555
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 221895 visits
# Running:  ['combo_dust_scale0_6_nslice3_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 61.6523  dipole: lon: 8.84381, lat: -75.5318, amp: 33.58
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 221764 visits
# Running:  ['combo_dust_scale0_2_nslice3_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 60.4123  dipole: lon: 16.8659, lat: -79.855, amp: 34.4897
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 221836 visits
# Running:  ['combo_dust_scale0_2_nslice2_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 60.4918  dipole: lon: 11.7109, lat: -82.6337, amp: 32.4651
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 222272 visits
# Running:  ['combo_dust_scale1_0_nslice2_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 60.7073  dipole: lon: 173.214, lat: -84.9651, amp: 31.5067
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 222131 visits
# Running:  ['combo_dust_scale0_9_nslice2_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:214: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 60.8832  dipole: lon: -169.841, lat: -85.039, amp: 30.4761
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 222101 visits
# Running:  ['combo_dust_scale0_6_nslice2_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:127: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:364: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:214: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 61.7695  dipole: lon: 23.8604, lat: -86.9047, amp: 29.2251
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 222203 visits
# Running:  ['combo_dust_scale0_8_nslice3_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:127: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:364: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:214: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 62.0559  dipole: lon: -3.65112, lat: -76.2199, amp: 32.0677
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 221963 visits
# Running:  ['combo_dust_scale0_4_nslice2_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:127: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:364: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:214: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 60.3071  dipole: lon: 12.9487, lat: -87.5583, amp: 31.6899
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 222305 visits
# Running:  ['combo_dust_scale0_8_nslice2_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:127: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:364: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:214: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 61.4012  dipole: lon: -136.88, lat: -87.804, amp: 29.9773
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldDec', 'filter', 'fieldRA']
# Found 221869 visits
# Running:  ['combo_dust_scale0_4_nslice3_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:127: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:364: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:214: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 60.9716  dipole: lon: 15.5535, lat: -76.7019, amp: 33.7906
#   mono, lon, lat, amp
# Plotting complete.

# %%
fp = make_rolling_footprints(nslice=2, scale=0.8)
hp.mollview(fp.footprint_list[0].footprints[2])
hp.mollview(fp.footprint_list[1].footprints[2])
hp.mollview(fp.footprint_list[2].footprints[1])

# %%
fp = make_rolling_footprints(nslice=3, scale=0.8)
hp.mollview(fp.footprint_list[1].footprints[2])

# %%
hp.mollview(fp.footprint_list[2].footprints[1])

# %%
hp.mollview(fp.footprint_list[3].footprints[2])

# %%
np.unique(fp.footprint_list[3].footprints[2])
# Out:
# array([0., 1.])

# %%
fp = make_rolling_footprints(nslice=2, scale=0.8)
hp.mollview(fp.footprint_list[1].footprints[2])

# %%
hp.mollview(fp.footprint_list[2].footprints[2])
