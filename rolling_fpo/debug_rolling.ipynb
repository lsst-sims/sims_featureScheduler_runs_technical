# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from rolling_fpo import make_rolling_footprints
import healpy as hp

# %%
fpo = make_rolling_footprints()

# %%
mjd0 = 59853.5

# %%
ack = fpo(mjd0+365*2)

# %%
hp.mollview(ack['r'])
